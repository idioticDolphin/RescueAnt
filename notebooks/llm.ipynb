# %%
from llama_cpp import Llama

# %%
llm = Llama(model_path="../models/Qwen3.5-4B-UD-Q4_K_XL.gguf")
# Out:
# llama_model_loader: loaded meta data with 46 key-value pairs and 426 tensors from ../models/Qwen3.5-4B-UD-Q4_K_XL.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = qwen35
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Qwen3.5-4B
# llama_model_loader: - kv   3:                           general.basename str              = Qwen3.5-4B
# llama_model_loader: - kv   4:                       general.quantized_by str              = Unsloth
# llama_model_loader: - kv   5:                         general.size_label str              = 4B
# llama_model_loader: - kv   6:                            general.license str              = apache-2.0
# ...

# %%
output = llm(
      "Write a hello world script in python", # Prompt
      max_tokens=640, # Generate up to 32 tokens
      #stop=["Q:"], # Stop generating just before the model would generate a new question
      echo=False # Do not Echo the prompt back in the output
) # Generate a completion, can also call create_completion

# Note that you have to dig into the output `choices` field to find the answer to
# your question.
print(output['choices'][0]['text'])
# Out:
# Llama.generate: recurrent/hybrid model requires full state reset
# llama_perf_context_print:        load time =    1212.10 ms
# llama_perf_context_print: prompt eval time =     941.16 ms /     7 tokens (  134.45 ms per token,     7.44 tokens per second)
# llama_perf_context_print:        eval time =   53662.72 ms /   504 runs   (  106.47 ms per token,     9.39 tokens per second)
# llama_perf_context_print:       total time =   55275.72 ms /   511 tokens
# llama_perf_context_print:    graphs reused =        502
# <think>
# Thinking Process:
#
# 1.  **Analyze the Request:**
#     *   Topic: Python programming.
#     *   Task: Write a "Hello World" script.
#     *   Language: Python.
#
# 2.  **Determine the Output:**
#     *   The core requirement is the code snippet.
#     *   It should be simple and standard.
#     *   It might be helpful to include a brief explanation or instructions on how to run it.
#
# 3.  **Draft the Code:**
# ...

# %%
def categorize_website(html):
    """
    TODO
    :param html:
    :return:
    """
    #TODO

# %%
def extract_from_list_site(site_content):
    """
    TODO
    :param site_content:
    :return:
    """
    #TODO

def extract_from_station_site(site_content):
    """
    TODO
    :param site_content:
    :return:
    """
    #TODO
